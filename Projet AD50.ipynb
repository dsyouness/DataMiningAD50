# %%
library(FactoMineR) #FactoMineR library
ecall.data <- read.csv(file="Ecall_csv.csv",header=TRUE, row.names=1, sep=";")

# %%
ecall.data
# Out:
#                            QAP_7_1_1 QAP_7_1_2 QAP_7_1_3 QAP_7_1_4 QAP_7_1_5
# Q4_1                       2          0        12        10        0
# Q4_2                       0          1         3         2        0
# Q4_3                       2         13        15         0        0
# Q5_1                       4          1        30        26        0
# Q5_2                       0          0         0         1        0
# Q10_1                      2          0         8         8        0
# Q10_2                      2          1        22        19        0
# Q11_2                      0          0         4         7        0
# Q11_3                      4          1        22        16        0
# Q11_4                      0          0         4         4        0
# Q12_2_2                    2          1        18        14        0
# Q12_2_3                    0          0         4        13        0
# ...

# %%
summary(ecall.data)
# Out:
#    QAP_7_1_1        QAP_7_1_2         QAP_7_1_3        QAP_7_1_4
#  Min.   :0.0000   Min.   : 0.0000   Min.   : 0.000   Min.   : 0.000
#  1st Qu.:0.0000   1st Qu.: 0.0000   1st Qu.: 2.000   1st Qu.: 1.000
#  Median :0.0000   Median : 0.0000   Median : 4.000   Median : 4.000
#  Mean   :0.9429   Mean   : 0.6286   Mean   : 6.657   Mean   : 6.029
#  3rd Qu.:2.0000   3rd Qu.: 1.0000   3rd Qu.: 8.500   3rd Qu.: 8.500
#  Max.   :4.0000   Max.   :13.0000   Max.   :30.000   Max.   :26.000
#
#    QAP_7_1_5   QAP_7_3_2        QAP_7_3_3        QAP_7_3_4       QAP_7_3_5
#  Min.   :0   Min.   : 0.000   Min.   : 0.000   Min.   :0.000   Min.   :0.0000
#  1st Qu.:0   1st Qu.: 1.000   1st Qu.: 3.000   1st Qu.:0.000   1st Qu.:0.0000
#  Median :0   Median : 2.000   Median : 6.000   Median :1.000   Median :0.0000
#  Mean   :0   Mean   : 3.057   Mean   : 9.229   Mean   :1.286   Mean   :0.7143
#  3rd Qu.:0   3rd Qu.: 4.000   3rd Qu.:14.000   3rd Qu.:2.000   3rd Qu.:1.0000
# ...

# %%
res.test.chi2 <- chisq.test(ecall.data[1:3,1:3])
res.test.chi2
# Out:
# Warning message in chisq.test(ecall.data[1:3, 1:3]):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  ecall.data[1:3, 1:3]
# X-squared = 9.2571, df = 4, p-value = 0.05498
