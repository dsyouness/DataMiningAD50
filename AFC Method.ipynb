# %% [markdown]
# # AFC

# %%
library("readxl")
my_data <- read_excel("Ecall.xlsx")
suppressWarnings( my_data )
# Out:
#    X__1
# 1  Questionnaire utilisateur
# 2  utilisation de lunettes pour conduire
# 3  utilisation de lentilles de contacts pour conduire
# 4  pas d'aides visuelles  pour conduire
# 5  utilsation de prothèses auditives pour conduire
# 6  pas d'utilsation de prothèses auditives pour conduire
# 7  conducteur très expérimenté
# 8  conducteur expérimenté
# 9  conduite défensive
# 10 conduite équilibrée
# 11 conduite offensive
# 12 dépasse rarement la limite de vitesse (plus de 10 %) sur les routes/autoroutes
# 13 dépasse parfois la limite de vitesse (plus de 10 %) en dépassant un autre véhicule
# 14 dépasse souvent la limite de vitesse (plus de 10 %) en dépassant un autre véhicule
# 15 dépasse rarement la limite de vitesse (plus de 10 %) lors d'un déplacement d'autres véhicules
# 16 dépasse parfois la limite de vitesse (plus de 10 %) lors d'un déplacement d'autres véhicules
# 17 dépasse souvent la limite de vitesse (plus de 10 %) lors d'un déplacement d'autres véhicules
# 18 Sexe
# ...

# %%
dim(my_data)
# Out:
# [1] 38 44
