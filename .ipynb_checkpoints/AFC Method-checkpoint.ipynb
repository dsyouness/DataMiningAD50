# %% [markdown]
# # AFC

# %%
library("readxl")
my_data <- read_excel("Ecall.xlsx",range = "B2:AR39")
suppressWarnings( my_data )
# Out:
#    X__1                       QAP_7_1_1 QAP_7_1_2 QAP_7_1_3 QAP_7_1_4 QAP_7_1_5
# 1  Q4_1                       2          0        12        10        0
# 2  Q4_2                       0          1         3         2        0
# 3  Q4_3                       2         13        15         0        0
# 4  Q5_1                       4          1        30        26        0
# 5  Q5_2                       0          0         0         1        0
# 6  Q10_1                      2          0         8         8        0
# 7  Q10_2                      2          1        22        19        0
# 8  Q11_2                      0          0         4         7        0
# 9  Q11_3                      4          1        22        16        0
# 10 Q11_4                      0          0         4         4        0
# 11 Q12_2_2                    2          1        18        14        0
# 12 Q12_2_3                    0          0         4        13        0
# ...

# %%
dim(my_data)
# Out:
# [1] 37 43

# %%
my_data
# Out:
#    X__1                       QAP_7_1_1 QAP_7_1_2 QAP_7_1_3 QAP_7_1_4 QAP_7_1_5
# 1  Q4_1                       2          0        12        10        0
# 2  Q4_2                       0          1         3         2        0
# 3  Q4_3                       2         13        15         0        0
# 4  Q5_1                       4          1        30        26        0
# 5  Q5_2                       0          0         0         1        0
# 6  Q10_1                      2          0         8         8        0
# 7  Q10_2                      2          1        22        19        0
# 8  Q11_2                      0          0         4         7        0
# 9  Q11_3                      4          1        22        16        0
# 10 Q11_4                      0          0         4         4        0
# 11 Q12_2_2                    2          1        18        14        0
# 12 Q12_2_3                    0          0         4        13        0
# ...
